# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("me/SaiaDesignChatbot.pdf")
SaiaDesign = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        SaiaDesign += text

# %%
print(SaiaDesign)
# Out:
# Who  We  Are
# Saia  Design  is  a  web-development  and  digital-marketing  agency  that  specializes  in
# high-quality,
#
# affordable
#
# websites
#
# for
#
# small
#
# businesses.
#
# We
#
# serve
#
# clients
#
# across
#
# the
#
# U.S.
#
# (with
#
# strong
#
# presence
#
# in
#
# Tennessee
#
# &
#
# Texas),
#
# helping
#
# local
#
# service
#
# providers
#
# grow
#
# through
#
# modern
#
# design,
#
# SEO,
#
# and
#
# automation.
#
# Our  Mission
# To  make  professional  websites  and  digital  marketing  simple,  affordable,  and  effective  for
# small
#
# businesses
#
# —
#
# so
#
# they
#
# can
#
# focus
#
# on
#
# running
#
# their
#
# business
#
# while
#
# we
#
# handle
#
# the
#
# rest.
#
#
# 🌐  What  We  Offer
# 1.  Website  Design  &  Development
# ●  Modern,  fast,  mobile-first  websites
#  ●  Built  to  convert  (clear  calls-to-action,  service  pages,  contact  forms)
#  ●  Custom  branding,  icons,  and  SEO-optimized  content
#  ●  Designed  in  our  signature  style  (clean,  bold,  Montserrat,  blue-white-orange  palette)
#
# 2.  Unlimited  Updates  (Included)
# Every  subscription  includes:
# ●  Unlimited  text/image  edits
#  ●  New  pages
#  ●  Blog  posts
#  ●  Service  updates
#  ●  Seasonal  changes
#  ●  Technical  maintenance
#  ●  Hosting,  SSL,  backups
#
# No  extra  charges.
# 3.  SEO  (Search  Engine  Optimization)
# ●  Local  SEO  tailored  for  small  businesses
#  ●  Google-ready  structure  (titles,  meta  descriptions,  alt-text)
#  ●  Keyword  targeting
#  ●  Google  Business  Profile  optimization
#  ●  Speed/performance  improvements
#
# 4.  AI  Tools  &  Automation
# ●  AI-generated  content
#  ●  Lead-collection  automations
#  ●  Chatbots  and  basic  AI  assistants
#  ●  Social  media  templates
#  ●  SEO  image  generation
#
# 5.  Branding  &  Creative
# ●  Logos,  icons,  custom  graphics
#  ●  Full  brand  kits
#  ●  Social  media  banners  and  templates
#  ●  Business  card  design
#
#  💰  How  Pricing  Works
# Simple  Subscription  Model
# ●  $80/month
#  ●  First  month  free
#  ●  Cancel  anytime
#
# Includes  hosting,  domain  connection,  maintenance,  unlimited  updates,  and  SEO.
# No  upfront  cost ,  no  hidden  fees,  no  contracts.
#
# 🛠  Our  Process
# 1.  Quick  Onboarding  (10–15  minutes)
# Client  provides:
# ●  Business  name
#  ●  Services
#  ●  Photos/videos
#  ●  Colors/logos  (if  available)
#
# 2.  Design  Phase  (2–5  days)
# We  create:
# ●  Homepage
#  ●  Services
#  ●  About  page
#  ●  Contact  page
#  ●  SEO  structure
#  ●  Mobile  layouts
#  ●  Custom  brand  look
#
# Client  reviews  and  gives  feedback.
# 3.  Revisions  (1–2  days)
# Unlimited  changes  until  the  client  loves  the  design.
# 4.  Launch
# We  connect  domain,  set  up  analytics,  SEO,  and  publish.
# Total  time:  5–7  days  on  average.
#
# ⭐  Why  Small  Businesses  Choose  Us
# ✔  Affordable  —  but  premium  quality
# Website  agencies  charge  $2,000–$10,000  upfront.  Our  model  offers  the  same  quality  for
# $80/month.
#
# ✔  Fast  turnaround
# Most  sites  are  delivered  within  a  week.
# ✔  We  handle  everything
# Clients  don’t  worry  about:
# ●  Hosting
#  ●  Edits
#  ●  SEO
#  ●  Maintenance
#  ●  Security
#  ●  Web  knowledge
#
# ✔  Unlimited  updates
# Unique  advantage  versus  traditional  agencies.
# ✔  Proven  results
# We  have  30+  active  clients ,  mostly  local  service  providers:
# ●  Electricians
#  ●  Landscaping  companies
#  ●  Auto  detailers
#  ●  Cleaning  services
#  ●  Restaurants
#  ●  Roadside  assistance
#  ●  Beauty  and  wellness
#  ●  Contractors
#  ●  Local  trades
#
# ✔  Human,  personal  support
# Direct  communication  with  the  founder  —  not  a  support  ticket  system.
#
# 📦  What’s  Included  in  Every  Website  ●  Fully  custom  design
#  ●  Contact  forms  with  lead  emails
#  ●  Google  Maps  +  Schema
#  ●  Mobile  +  tablet  optimization
#  ●  SEO  titles  &  meta  descriptions
#  ●  High-performance  hosting
#  ●  SSL  security
#  ●  Speed  optimization
#  ●  Accessibility  adjustments
#  ●  Analytics  setup
#  ●  Image  compression  &  alt-text
#
#
# ❓  FAQs  (Covers  99%  of  Questions)
# How  long  does  the  website  take?
# 5–7  days  on  average.
# Is  there  a  contract?
# No.  Month-to-month  subscription.
# Can  I  update  the  site  myself?
# Yes,  but  you  don’t  need  to  —  unlimited  updates  are  included.
# Do  you  write  content  for  me?
# Yes.  We  write  clean,  SEO-optimized  text  for  each  service.  Do  you  take  photos  or  videos?
# Clients  typically  provide  them,  but  we  can  use  AI  or  stock  if  needed.
# Can  I  cancel  anytime?
# Yes.  No  cancellation  fees.
# Do  you  do  e-commerce?
# Yes  —  product  limits  depend  on  the  plan.
# Can  you  redesign  my  old  site?
# Absolutely.  Most  clients  switch  to  us  for  better  quality  and  easier  updates.
# Can  you  rank  me  on  Google?
# We  provide  strong  local  SEO  fundamentals  that  help  your  ranking  grow  over  time.
# How  To  Schedule  a  Free  Demo  Website?
# Text  731-394-7547  what  day  you  need  the  demo  by  and  what  times  you  are  available  along  with
# a
#
# link
#
# to
#
# the
#
# social
#
# media
#
# of
#
# the
#
# Company.
#
#
# 📈  Our  Ideal  Clients
# Small  businesses  that  want:
# ●  A  professional  online  presence
#  ●  More  leads
#  ●  A  modern,  fast  website
#  ●  Better  SEO
#  ●  A  simple,  affordable  monthly  plan
#  ●  Someone  to  handle  everything  for  them
#  Perfect  for:
#
# Contractors,
#
# plumbers,
#
# electricians,
#
# landscapers,
#
# detailers,
#
# HVAC
#
# companies,
#
# gyms,
#
# barber
#
# shops,
#
# restaurants,
#
# tutors,
#
# real
#
# estate
#
# professionals,
#
# and
#
# many
#
# others.
#
#
# ✨  One-Sentence  Pitch
# “Saia  Design  gives  small  businesses  a  premium  website,  unlimited  updates,  and  full  SEO—all
# for
#
# $80/month
#
# with
#
# the
#
# first
#
# month
#
# free.”
#
#
# If  you  want,  I  can  also  create:
# ✅  A  short  version
#
# ✅
#
# A
#
# 30-second
#
# elevator
#
# pitch
#
#
# ✅
#
# A
#
# script
#
# for
#
# calls
#
# or
#
# DMs
#
#
# ✅
#
# A
#
# brochure
#
# version
#
#
# ✅
#
# A
#
# website
#
# “About
#
# Us”
#
# version
#
#
# ✅
#
# A
#
# version
#
# in
#
# Spanish
#
# Just  tell  me  which  one  you  want  next.

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = ""

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s services, polocies, contact info, reputation. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{SaiaDesign}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as . You are answering questions on 's website, particularly questions related to 's services, polocies, contact info, reputation. Your responsibility is to represent  for interactions on the website as faithfully as possible. You are given a summary of 's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nSaia Design is a web-development and digital-marketing agency that builds modern, high-quality, and affordable websites for small businesses. We focus on helping local service providers grow through clean design, strong SEO, and simple monthly pricing. Our subscription model includes hosting, security, and unlimited updates, so clients never have to worry about technical work or extra fees.\n\nWith more than 30 active clients across Tennessee, Texas, and the U.S., we specialize in fast turnarounds, mobile-first design, and websites built to convert leads. Our mission is to make professional websites accessible to every small business—giving them a powerful online presence without high upfront costs or complexity.\n\n## LinkedIn Profile:\nWho  We  Are  \nSaia  Design  is  a  web-development  and  digital-marketing  agency  that  specializes  in  \nhigh-quality,\n \naffordable\n \nwebsites\n \nfor\n \nsmall\n \nbusinesses.\n \nWe\n \nserve\n \nclients\n \nacross\n \nthe\n \nU.S.\n \n(with\n \nstrong\n \npresence\n \nin\n \nTennessee\n \n&\n \nTexas),\n \nhelping\n \nlocal\n \nservice\n \nproviders\n \ngrow\n \nthrough\n \nmodern\n \ndesign,\n \nSEO,\n \nand\n \nautomation.\n \nOur  Mission  \nTo  make  professional  websites  and  digital  marketing  simple,  affordable,  and  effective  for  \nsmall\n \nbusinesses\n \n—\n \nso\n \nthey\n \ncan\n \nfocus\n \non\n \nrunning\n \ntheir\n \nbusiness\n \nwhile\n \nwe\n \nhandle\n \nthe\n \nrest.\n \n \n🌐  What  We  Offer  \n1.  Website  Design  &  Development  \n●  Modern,  fast,  mobile-first  websites  \n ●  Built  to  convert  (clear  calls-to-action,  service  pages,  contact  forms)  \n ●  Custom  branding,  icons,  and  SEO-optimized  content  \n ●  Designed  in  our  signature  style  (clean,  bold,  Montserrat,  blue-white-orange  palette)  \n \n2.  Unlimited  Updates  (Included)  \nEvery  subscription  includes:  \n●  Unlimited  text/image  edits  \n ●  New  pages  \n ●  Blog  posts  \n ●  Service  updates  \n ●  Seasonal  changes  \n ●  Technical  maintenance  \n ●  Hosting,  SSL,  backups  \n \nNo  extra  charges.  \n3.  SEO  (Search  Engine  Optimization)  \n●  Local  SEO  tailored  for  small  businesses  \n ●  Google-ready  structure  (titles,  meta  descriptions,  alt-text)  \n ●  Keyword  targeting  \n ●  Google  Business  Profile  optimization  \n ●  Speed/performance  improvements  \n \n4.  AI  Tools  &  Automation  \n●  AI-generated  content  \n ●  Lead-collection  automations  \n ●  Chatbots  and  basic  AI  assistants  \n ●  Social  media  templates  \n ●  SEO  image  generation  \n \n5.  Branding  &  Creative  \n●  Logos,  icons,  custom  graphics  \n ●  Full  brand  kits  \n ●  Social  media  banners  and  templates  \n ●  Business  card  design  \n \n 💰  How  Pricing  Works  \nSimple  Subscription  Model  \n●  $80/month  \n ●  First  month  free  \n ●  Cancel  anytime  \n \nIncludes  hosting,  domain  connection,  maintenance,  unlimited  updates,  and  SEO.  \nNo  upfront  cost ,  no  hidden  fees,  no  contracts.   \n \n🛠  Our  Process  \n1.  Quick  Onboarding  (10–15  minutes)  \nClient  provides:  \n●  Business  name  \n ●  Services  \n ●  Photos/videos  \n ●  Colors/logos  (if  available)  \n \n2.  Design  Phase  (2–5  days)  \nWe  create:  \n●  Homepage  \n ●  Services  \n ●  About  page  \n ●  Contact  page  \n ●  SEO  structure  \n ●  Mobile  layouts  \n ●  Custom  brand  look  \n \nClient  reviews  and  gives  feedback.  \n3.  Revisions  (1–2  days) ...

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.0-flash", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply

# %%
evaluate(reply, "do you hold a patent?", messages[:1])

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
